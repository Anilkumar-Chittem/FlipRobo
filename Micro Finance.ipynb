# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Mirco.csv")

# %%
data
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %% [markdown]
# # EDA

# %%
data.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
data.dtypes
# Finding out the type of data types we have
# there are 3 columns which are of object data type 
# rest all are integer and float
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# ...

# %%
data.isnull().any()
# there are no null values
# Out:
# Unnamed: 0              False
# label                   False
# msisdn                  False
# aon                     False
# daily_decr30            False
# daily_decr90            False
# rental30                False
# rental90                False
# last_rech_date_ma       False
# last_rech_date_da       False
# last_rech_amt_ma        False
# cnt_ma_rech30           False
# fr_ma_rech30            False
# sumamnt_ma_rech30       False
# medianamnt_ma_rech30    False
# medianmarechprebal30    False
# cnt_ma_rech90           False
# fr_ma_rech90            False
# sumamnt_ma_rech90       False
# medianamnt_ma_rech90    False
# medianmarechprebal90    False
# cnt_da_rech30           False
# fr_da_rech30            False
# cnt_da_rech90           False
# fr_da_rech90            False
# cnt_loans30             False
# amnt_loans30            False
# maxamnt_loans30         False
# medianamnt_loans30      False
# cnt_loans90             False
# amnt_loans90            False
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,18))
sns.heatmap(data.corr(),cmap='Blues')

# %%
# 1.payback 30 and 90 are highly co- related with each other(Average payback time in days over last 30,90 days)
#2.medianamnt loan 90 and 30 are highly co-related(Median of amounts of loan taken by the user in last 3090 days)
#3.amnt loan 30and 90 are highly co related with one another(Total amount of loans taken by user in last 30,90 days)
#4.cnt loan 30 and 90 are highly co related with one (Number of loans taken by user in last 30,90 days)
#5.cnt loan and cnt man rech 30 are aslo co- related with one another(Number of times main account got recharged in last 30 days)
#6.daily_decr30,90(Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)) is co- related with amnt loan90,maxa mnth  loan 90, sumamnt_ma_rech 30,rental 30,90
#7.daily decr 30 and 90 are also co -related 
#8.rental 30 and 90 are co-related 
#9.medianamnt_ma_rech90 is co related with last_rech_date_ma(Number of days till last recharge of main account)
#10.cnt ma rech 30 (Number of times main account got recharged in last 30 days) is co related with cnt ma rech 90
#11.sumamnt_ma_rech90(Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)) is co related with sumamnt_ma_rech 30
#12.last_rech_amt_ma(Amount of last recharge of main account (in Indonesian Rupiah)) with mediant man rech 90 
#13.amnt loans30 is co realted with cnt loans30
#14.amnt loan 90 and cnt loans 30 
# THE ABOVE ARE THE COLUMNS THAT ARE CO-RELATAE WITH ONE ANOTHER WHICH IS HELPFUL FOR VISUALIZING THE

# %%
data.describe()
# all the columns other than label are stating with a -ve value 
#there is huge difference between 75% and max so there are outliers present in our data 
#aon	daily_decr30	daily_decr90	rental30	rental90	last_rech_date_ma	last_rech_date_da these all have a high std
#std is higher than mean in the abaove mentioned ouliers columns
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# ...

# %%
# seeing the distrubion of the data
data.hist(figsize=(20,18))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C9E9A710D0>,
# ...
#       dtype=object)

# %%
data=data.drop('Unnamed: 0',axis=1 )

# %%
data
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
data.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
from sklearn import preprocessing

# %%
l=preprocessing.LabelEncoder()

# %%
data['msisdn']=l.fit_transform(data['msisdn'])

# %%
data['pcircle']=l.fit_transform(data['pcircle'])

# %%
plt.figure(figsize=(24,20),facecolor='white')
plot=1
for i in data:
    if plot<=36:
        ax=plt.subplot(5,7,plot)
        sns.distplot(data[i])
        plt.xlabel(i,fontsize=10)
    plot+=1
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.countplot('label',data=data)
# from this it is clear that the data is unbalanced 
# since it is a classification problem we need to use Recall,Precesion,F-beta

# %%
sns.lineplot(x='payback30',y='payback90',data=data)
#Average payback time in days over last 30 days and 90  are linear so paying back is same for 90 days also

# %%
sns.countplot(x='pcircle',data=data)
# there is only one type in pcircle and the value ranges from upto 20k

# %%
sns.barplot(x='maxamnt_loans90',y='label',data=data)
# there are 3 types of loans given 0,6,12 out of which 0 loan is highest and giving 6 loan is the leas

# %%
sns.lineplot(x='amnt_loans90',y='cnt_loans30',data=data,hue='label')
# from this graph it is clear that as the total amount of loans taken in last 90 days is equal to number of loans taken in 30

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="fr_ma_rech90",hue='maxamnt_loans90',data=data)
# from this max frequency 6 reacharge is used more than other loans

# %%
sns.lineplot(x='medianamnt_ma_rech90',y='last_rech_date_ma',data=data)
# from this it is clear that median reacharge in last 90 days is high from 500 o 1000 Number of days till last recharge of main account

# %%
data.shape
#16767
#192828
# Out:
# (209593, 36)

# %%
data.shape
# Out:
# (209593, 36)

# %%
#Feature selecting with the help of co-relation map and dropping unecessary columns
col=['daily_decr30','daily_decr90','cnt_ma_rech30','cnt_ma_rech90','sumamnt_ma_rech30','sumamnt_ma_rech90','amnt_loans90','amnt_loans30','label','cnt_loans30']
new=data.loc[:, data.columns.intersection(col)]

# %%
new['label'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
column=['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
       'rental90', 'last_rech_date_ma', 'last_rech_date_da',
       'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
       'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
       'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
       'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
       'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
       'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
       'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
       'payback90', 'pcircle']
from scipy.stats import zscore
z_score=abs(zscore(new))
print(new.shape)
data_final=new.loc[(z_score<3).all(axis=1)]
print(data_final.shape)
# Out:
# (209593, 10)
# (195737, 10)

# %%
data_final
# Out:
#         label  daily_decr30  daily_decr90  cnt_ma_rech30  sumamnt_ma_rech30  \
# 0           0   3055.050000   3065.150000              2             3078.0
# 1           1  12122.000000  12124.750000              1             5787.0
# 2           1   1398.000000   1398.000000              1             1539.0
# 3           1     21.228000     21.228000              0                0.0
# 4           1    150.619333    150.619333              7            20029.0
# ...       ...           ...           ...            ...                ...
# 209588      1    151.872333    151.872333              3            10404.0
# 209589      1     36.936000     36.936000              4             3092.0
# 209590      1  11843.111667  11904.350000              5             9334.0
# 209591      1  12488.228333  12574.370000              5            12154.0
# 209592      1   4489.362000   4534.820000              2             9065.0
#
# ...

# %%
print(new.shape)
print(data_final.shape)
# ouliers are removed using quantile
# Out:
# (209593, 10)
# (195737, 10)

# %%
for column in data_final:
    plt.figure()
    data.boxplot([column])
# from this it is clear that all the columns other than p circle have outliers so if we remove them out

# %%
data_final['label'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# the skewness is removed from the data
# now we need to split the data

# %%
da_x=data_final.drop(columns='label',axis=1)
y=data_final[['label']]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2


sc=StandardScaler()
x=sc.fit_transform(da_x)
x=pd.DataFrame(x,columns=da_x.columns)

# %%
x
# Out:
#         daily_decr30  daily_decr90  cnt_ma_rech30  sumamnt_ma_rech30  \
# 0          -0.161539     -0.204189      -0.448035          -0.486526
# 1           1.393650      1.154007      -0.779825          -0.053863
# 2          -0.445761     -0.454124      -0.779825          -0.732324
# 3          -0.681909     -0.660527      -1.111616          -0.978122
# 4          -0.659715     -0.641129       1.210919           2.220768
# ...              ...           ...            ...                ...
# 195732     -0.659500     -0.640941      -0.116244           0.683531
# 195733     -0.679215     -0.658172       0.215547          -0.484290
# 195734      1.345815      1.120965       0.547338           0.512638
# 195735      1.456467      1.221413       0.547338           0.963029
# 195736      0.084478      0.016141      -0.448035           0.469676
#
#         cnt_ma_rech90  sumamnt_ma_rech90  cnt_loans30  amnt_loans30  \
# 0           -0.653423          -0.646532    -0.226417     -0.287095
# ...

# %%
data_final['label'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# since we have outliers we need to use the following algorithim so that our model doesnt get affected 
# Naivye Bayes Classifier--- Not Sensitive To Outliers
# SVM-------- Not Sensitive To Outliers
# Logistic Regression------- Sensitive To Outliers
# Decision Tree Regressor or Classifier---- Not Sensitive
# Ensemble(RF,XGboost,GB)------- Not Sensitive
# KNN--------Not Sensitive

# %%
# now the data is ready for training and testing the data 
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=10,test_size=0.25)
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve, roc_auc_score

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier

# %%
y_test.shape
# Out:
# (36810, 1)

# %%
lg=LogisticRegression()
grid={'penalty':['l2']}
clf=GridSearchCV(lg,grid,cv=5,scoring='f1_macro')
lg.fit(x_train,y_train)
y_pred=lg.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

# from confusion matrix it is clear that Fasle postive is more which we need to decrease done by using oher alg 
# we can see the re precision and recall is very low
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [[    0  6592]
#  [    0 42343]]
# 0.8652906917339328
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      6592
#            1       0.87      1.00      0.93     42343
#
#     accuracy                           0.87     48935
#    macro avg       0.43      0.50      0.46     48935
# weighted avg       0.75      0.87      0.80     48935
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
bestfeatures = SelectKBest(score_func=chi2)
fit = bestfeatures.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-fef922970be5> in <module>
#       2 from sklearn.feature_selection import chi2
#       3 bestfeatures = SelectKBest(score_func=chi2)
# ----> 4 fit = bestfeatures.fit(x,y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     350                             % (self.score_func, type(self.score_func)))
#     351
# --> 352         self._check_params(X, y)
#     353         score_func_ret = self.score_func(X, y)
#     354         if isinstance(score_func_ret, (list, tuple)):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in _check_params(self, X, y)
#     521     def _check_params(self, X, y):
#     522         if not (self.k == "all" or 0 <= self.k <= X.shape[1]):
# ...

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(x,y)

print(model.feature_importances_)
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.plot(kind='barh')
plt.show()
# Out:
# <ipython-input-31-953e2056fccc>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x,y)
# [0.32692717 0.29270763 0.06325843 0.08292912 0.0514464  0.10126967
#  0.02578402 0.02475855 0.03091902]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-953e2056fccc> in <module>
#       6 feat_importances = pd.Series(model.feature_importances_, index=x.columns)
#       7 feat_importances.plot(kind='barh')
# ----> 8 plt.show()
#
# NameError: name 'plt' is not defined

# %%
nb=GaussianNB()
nb.fit(x_train,y_train)
y_pred=nb.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 5783   809]
#  [18856 23487]]
# 0.5981403903136814
#               precision    recall  f1-score   support
#
#            0       0.23      0.88      0.37      6592
#            1       0.97      0.55      0.70     42343
#
#     accuracy                           0.60     48935
#    macro avg       0.60      0.72      0.54     48935
# weighted avg       0.87      0.60      0.66     48935
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
knc=KNeighborsClassifier()

knc.fit(x_train,y_train)
y_pred=knc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# <ipython-input-33-92dea41d0e83>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   knc.fit(x_train,y_train)
# [[ 2773  3819]
#  [ 1432 40911]]
# 0.8926943905180341
#               precision    recall  f1-score   support
#
#            0       0.66      0.42      0.51      6592
#            1       0.91      0.97      0.94     42343
#
#     accuracy                           0.89     48935
#    macro avg       0.79      0.69      0.73     48935
# weighted avg       0.88      0.89      0.88     48935

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
y_pred=dtc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 3289  3303]
#  [ 3833 38510]]
# 0.8541739041585777
#               precision    recall  f1-score   support
#
#            0       0.46      0.50      0.48      6592
#            1       0.92      0.91      0.92     42343
#
#     accuracy                           0.85     48935
#    macro avg       0.69      0.70      0.70     48935
# weighted avg       0.86      0.85      0.86     48935

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# <ipython-input-29-ce6596c369b7>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(x_train,y_train)
# [[ 2918  3674]
#  [ 1836 40507]]
# 0.8874016552569736
#               precision    recall  f1-score   support
#
#            0       0.61      0.44      0.51      6592
#            1       0.92      0.96      0.94     42343
#
#     accuracy                           0.89     48935
#    macro avg       0.77      0.70      0.73     48935
# weighted avg       0.88      0.89      0.88     48935

# %%
adc=AdaBoostClassifier()
adc.fit(x_train,y_train)
y_pred=adc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
pred_prob1 = adc.predict_proba(x_test)
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob1[:,1], pos_label=1)
auc_score1 = roc_auc_score(y_test, pred_prob1[:,1])
print(auc_score1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [[ 1659  4933]
#  [  300 42043]]
# 0.8930622254010422
#               precision    recall  f1-score   support
#
#            0       0.85      0.25      0.39      6592
#            1       0.89      0.99      0.94     42343
#
#     accuracy                           0.89     48935
#    macro avg       0.87      0.62      0.66     48935
# weighted avg       0.89      0.89      0.87     48935
#
# 0.844936846156871

# %%
svc=SVC()
svc.fit(x_train,y_train)

y_pred=svc.predict(x_test)
y_pred=svc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [[    0  6592]
#  [    0 42343]]
# 0.8652906917339328
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      6592
#            1       0.87      1.00      0.93     42343
#
#     accuracy                           0.87     48935
#    macro avg       0.43      0.50      0.46     48935
# weighted avg       0.75      0.87      0.80     48935
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
xbc=XGBClassifier()
xbc.fit(x_train,y_train)

y_pred=xbc.predict(x_test)
y_pred=xbc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [[ 2446  4146]
#  [  738 41605]]
# 0.9001941350771432
#               precision    recall  f1-score   support
#
#            0       0.77      0.37      0.50      6592
#            1       0.91      0.98      0.94     42343
#
#     accuracy                           0.90     48935
#    macro avg       0.84      0.68      0.72     48935
# weighted avg       0.89      0.90      0.88     48935

# %%
import joblib

# %%
joblib.dump(adc,"MicroFinance.obj")
# Out:
# ['MicroFinance.obj']

# %%
# I am finalising this model because 
1. out of all the models in ada boost classifier  the falese positive rate is less 
2. from the classification report for 0 and 1 the precision and recall has a good score
3. we also got accuracy score of 89%
