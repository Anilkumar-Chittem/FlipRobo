# %%
# !pip install selenium

# %%
import selenium as SL
import pandas as pd
from selenium import webdriver

# %%
web=webdriver.Chrome(r"C:\Users\Anil Kumar Reddy\chromedriver.exe")

# %%
url='https://www.naukri.com/data-scientist-jobs-in-bangalore?k=data%20scientist&l=bangalore'

# %%
web.get(url)

# %%
job_title=[]
loca=[]
company_name=[]
job_description=[]

# %%
title=web.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")

# %%
title
for i in title[0:10]:
    tag=i.text
    job_title.append(tag)

# %%
location=loca[0:10]

# %%
len(location)
# Out:
# 10

# %%
loc=web.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in loc[0:10]:
    l=i.text
    loca.append(l)

# %%
company=web.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")

# %%
for i in company[0:10]:
    co=i.text
    company_name.append(co)

# %%
descr=web.find_elements_by_xpath("//div[@class='job-description fs12 grey-text']")
for i in descr[0:10]:
    de=i.text
    job_description.append(de)

# %%
describe=job_description[10:]

# %%
len(job_description)
# Out:
# 10

# %%
ans1=pd.DataFrame({})
ans1['Title']=job_title
ans1['Location']=location
ans1['Companyname']=company_name
ans1['Jobdescription']=job_description

# %%
#quesioin 1
ans1
# Out:
#                                                Title  \
# 0              Data Scientist/Data Analyst-immediate
# 1  HCL hiring Data scientist with exp in machine ...
# 2                  Data Scientist - Machine Learning
# 3                  Data Scientist - Machine Learning
# 4                  Data Scientist - Machine Learning
# 5                              Senior Data Scientist
# 6  Software Developer - Data Scientist / NLP / Ma...
# 7                                 Sr. Data Scientist
# 8  Data Scientist - Machine Learning - Remote Wor...
# 9                                     Data Scientist
#
#                                   Location  \
# 0      Chennai, Pune, Bengaluru, Hyderabad
# 1                                Bengaluru
# 2                                Bengaluru
# 3                                Bengaluru
# 4                                Bengaluru
# 5                                Bengaluru
# 6                    Bengaluru / Bangalore
# ...

# %%
link1="https://www.naukri.com/data-analyst-jobs-in-bangalore?k=data%20analyst&l=bangalore"

# %%
web.get(link1)

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]
t=web.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in t[0:10]:
    ti=i.text
    job_title.append(ti)

# %%
l=web.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in l[0:10]:
    li=i.text
    job_location.append(li)

# %%
c=web.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
for i in c[0:10]:
    ci=i.text
    company_name.append(ci)

# %%
e=web.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']")
for i in e[0:10]:
    ei=i.text
    experience_required.append(ei)

# %%
ans2=pd.DataFrame({})
ans2['Title']=job_title
ans2['Locaion']=job_location
ans2['CompanyName']=company_name
ans2['Expreience Required']=experience_required

# %%
#Question 2
ans2
# Out:
#                                             Title  \
# 0           Data Scientist/Data Analyst-immediate
# 1                                    Data Analyst
# 2                                    Data Analyst
# 3           ID&A - Data Analyst - Informatica MDM
# 4                                    Data Analyst
# 5                                    Data Analyst
# 6                                    Data Analyst
# 7  Business Data Analyst - Database Design/Mining
# 8                 Data Analyst - MySQL/PostgreSQL
# 9     Hiring For Data Analyst On Contractual Role
#
#                                              Locaion  \
# 0                Chennai, Pune, Bengaluru, Hyderabad
# 1                                          Bengaluru
# 2                       Mumbai, Bengaluru, Hyderabad
# 3                                          Bengaluru
# 4                                          Bengaluru
# 5                                 Bengaluru, Kolkata
# ...

# %%
url2="https://www.naukri.com/data-scientist-jobs?k=data%20scientist&cityType=25.9.31&ctcFilter=3to6"

# %%
web.get(url2)

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]
t=web.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in t[0:10]:
    ti=i.text
    job_title.append(ti)
l=web.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in l[0:10]:
    li=i.text
    job_location.append(li)
c=web.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
for i in c[0:10]:
    ci=i.text
    company_name.append(ci)
e=web.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']")
for i in e[0:10]:
    ei=i.text
    experience_required.append(ei)

# %%
ans3=pd.DataFrame({})
ans3['Title']=job_title
ans3['Location']=job_location
ans3['CompanyName']=company_name
ans3['Expreience Required']=experience_required

# %%
#question 3
ans3
# Out:
#                                                Title  \
# 0           Data Scientist - Python/Machine Learning
# 1     Tech Mahindra hiring For Data Scientist- Noida
# 2  Data Scientist - Commercial Planning and Analysis
# 3                                     Data Scientist
# 4  Data Scientist - Machine Learning/ Artificial ...
# 5  GCP Skilled Analytics Resources (Data engineer...
# 6                                     Data Scientist
# 7                    Data Scientist Machine Learning
# 8                                     Data Scientist
# 9                  Business Analyst - Data Scientist
#
#                           Location                            CompanyName  \
# 0                            Noida                                  Jubna
# 1                            Noida                      tech mahindra ltd
# 2               Delhi NCR, Gurgaon                 Air Asia India Limited
# 3  Faridabad, Delhi NCR, Ghaziabad                       Amity University
# ...

# %%
url3='https://www.glassdoor.co.in/Job/noida-data-scientist-jobs-SRCH_IL.0,5_IC4477468_KO6,20.htm'

# %%
web.get(url3)

# %%
company_name=[]
No_days_ago=[]
Rating=[]
c=web.find_elements_by_xpath("//div[@class='jobHeader d-flex justify-content-between align-items-start']")
for i in c[0:10]:
    ci=i.text
    company_name.append(ci)
n=web.find_elements_by_xpath("//div[@class='d-flex align-items-end pl-std css-mi55ob']")
for i in n[0:10]:
    ni=i.text
    No_days_ago.append(ni)
r=web.find_elements_by_xpath("//div[@class='d-flex flex-column css-fbt9gv e1rrn5ka2']")
for i in r[0:10]:
    ri=i.text
    Rating.append(ri)

# %%
ans4=pd.DataFrame({})
ans4['Company Name']=company_name
ans4['Posted befor']=No_days_ago
ans4['Rating']=Rating

# %%
ans4
# Out:
#                              Company Name Posted befor Rating
# 0                               BlackRock          15d    4.1
# 1                                 Genpact           8d    3.8
# 2  Terra Economics & Analytics Lab (TEAL)           8d    4.9
# 3      Builder.ai - What would you Build?          22d    3.6
# 4                               Donaldson          24h    3.8
# 5                                Brickred          26d    3.7
# 6                         Priority Vendor           7d      4
# 7                         abc consultants           7d    4.2
# 8                    Gauge Data Solutions           7d    3.1
# 9                               Algoscale           7d    3.7

# %%
url4="https://www.glassdoor.co.in/Job/noida-data-scientist-jobs-SRCH_IL.0,5_IC4477468_KO6,20.htm?srs=RECENT_SEARCHES "
web.get(url4)
company_name=[]
salries=[]
avg_sal=[]
min_sal=[]
max_sal=[]
Rating=[]

c=web.find_elements_by_xpath("//div[@class='jobHeader d-flex justify-content-between align-items-start']")
for i in c[0:10]:
    ci=i.text
    company_name.append(ci)
a=web.find_elements_by_xpath("//div[@class='strong']")
sal=web.find_elements_by_xpath("//span[@class='css-1imh2hq e1wijj242']")
for i in sal[0:10]:
    si=i.text
    min_sal.append(si)
r=web.find_elements_by_xpath("//span[@class='css-1m5m32b e1tk4kwz2']")
for i in r[0:10]:
    ri=i.text
    Rating.append(ri)    
ag=web.find_elements_by_xpath("//div[@class='strong']")
for i in ag:
    a1=i.text
    avg_sal.append(a1)

# %%
# Unable to scrape rating and avg sal (getting only single element)
ans5=pd.DataFrame({})
ans5['Company Name']=company_name
ans5['Min-Max Salary']=min_sal

# %%
ans5
# Out:
#                        Company Name                   Min-Max Salary
# 0                         HDFC Bank  ₹700K - ₹1,500K (Employer Est.)
# 1                    WSD Consultant    ₹180K - ₹300K (Employer Est.)
# 2                         QuantumIT  ₹800K - ₹1,400K (Employer Est.)
# 3                          Techlive            ₹600K (Employer Est.)
# 4                    Biz2Credit Inc  ₹800K - ₹1,600K (Employer Est.)
# 5      Salasar New Age Technologies    ₹480K - ₹720K (Employer Est.)
# 6  Simpplr Software India Pvt. Ltd.  ₹600K - ₹1,800K (Employer Est.)
# 7   ANI Calls India Private Limited            ₹120K (Employer Est.)
# 8      Salasar New Age Technologies  ₹800K - ₹1,600K (Employer Est.)
# 9                   SearchUrCollege  ₹900K - ₹1,600K (Employer Est.)

# %%
url5="https://www.flipkart.com/search?q=sunglasses&sid=26x&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=sunglasses%7CSunglasses&requestId=9e62fd88-2339-405d-946b-ecea2f9e4151&as-searchtext=sun"
web.get(url5)
brand=[]
prd_descr=[]
price=[]
dis=[]
b=web.find_elements_by_xpath("//div[@class='_2WkVRV']")
for i in b[0:]:
    bi=i.text
    brand.append(bi)
p=web.find_elements_by_xpath("//a[@class='IRpwTa']")
for i in p[0:100]:
    pi=i.text
    prd_descr.append(pi)
pr=web.find_elements_by_xpath("//div[@class='_30jeq3']")
for i in pr[0:100]:
    ci=i.text
    price.append(ci)
d=web.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
for  i in d[0:100]:
    di=i.text
    dis.append(di)

# %%
len(dis)
# Out:
# 40

# %%
url51="https://www.flipkart.com/search?q=sunglasses&sid=26x&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=sunglasses%7CSunglasses&requestId=9e62fd88-2339-405d-946b-ecea2f9e4151&as-searchtext=sun&page=2"
web.get(url51)
brand1=[]
prd_descr12=[]
price1=[]
dis1=[]
b1=web.find_elements_by_xpath("//div[@class='_2WkVRV']")
for i in b1:
    bi=i.text
    brand1.append(bi)
p=web.find_elements_by_xpath("//a[@class='IRpwTa']")
for i in p[0:100]:
    pi=i.text
    prd_descr12.append(pi)
pr=web.find_elements_by_xpath("//div[@class='_30jeq3']")
for i in pr[0:100]:
    ci=i.text
    price1.append(ci)
d=web.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
for  i in d[0:100]:
    di=i.text
    dis1.append(di)

# %%
len(dis1)
# Out:
# 40

# %%
url52="https://www.flipkart.com/search?q=sunglasses&sid=26x&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=sunglasses%7CSunglasses&requestId=9e62fd88-2339-405d-946b-ecea2f9e4151&as-searchtext=sun&page=3"
web.get(url52)
brand2=[]
prd_descr2=[]
price2=[]
dis2=[]
b2=web.find_elements_by_xpath("//div[@class='_2WkVRV']")
for i in b2[0:20]:
    bi=i.text
    brand2.append(bi)
p=web.find_elements_by_xpath("//a[@class='IRpwTa']")
for i in p:
    pi=i.text
    prd_descr2.append(pi)
pr=web.find_elements_by_xpath("//div[@class='_30jeq3']")
for i in pr[0:20]:
    ci=i.text
    price2.append(ci)
d=web.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
for  i in d[0:20]:
    di=i.text
    dis2.append(di)

# %%
len(dis2)
# Out:
# 20

# %%
url53='https://www.flipkart.com/search?q=sunglasses&sid=26x&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=sunglasses%7CSunglasses&requestId=9e62fd88-2339-405d-946b-ecea2f9e4151&as-searchtext=sun&page=4'
web.get(url53)
prd_descr3=[]
p3=web.find_elements_by_xpath("//a[@class='IRpwTa']")
for i in p3[0:11]:
    pi=i.text
    prd_descr3.append(pi)

# %%
len(prd_descr3)
# Out:
# 11

# %%
ans6=pd.DataFrame({})
ans6['Brand Name']=brand+brand1+brand2

ans6['price']=price+price1+price2
ans6['discount']=dis+dis1+dis2
ans6['Product description']=prd_descr+prd_descr12+prd_descr2+prd_descr3

# %%
#question 6
ans6
# Out:
#           Brand Name price discount  \
# 0     FDA COLLECTION  ₹199  84% off
# 1             Riffko  ₹170  85% off
# 2   shah collections  ₹219  78% off
# 3         Phenomenal  ₹399  80% off
# 4           Fastrack  ₹559  30% off
# ..               ...   ...      ...
# 95          Badfella  ₹210  78% off
# 96          Fastrack  ₹698  12% off
# 97    ROZZETTA CRAFT  ₹426  78% off
# 98  shah collections  ₹306  81% off
# 99    ROZZETTA CRAFT  ₹404  84% off
#
#                                   Product description
# 0   Gradient, Mirrored, UV Protection Round, Round...
# 1   UV Protection, Polarized, Mirrored Rectangular...
# 2   UV Protection, Mirrored Retro Square Sunglasse...
# 3   Gradient, UV Protection Wayfarer Sunglasses (F...
# 4          UV Protection Round Sunglasses (Free Size)
# ..                                                ...
# 95             UV Protection Wayfarer Sunglasses (56)
# 96  UV Protection Round, Oval, Spectacle , Clubmas...
# ...

# %%
#quesion- 7
# unable to scrape this whole data 
url6="https://www.flipkart.com/apple-iphone-11-black-64-gb/p/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZE3ENS&marketplace=FLIPKART&srno=s_1_2&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&fm=SEARCH&iid=d8a6e448-56d9-44da-91b9-80e9c988a643.MOBFWQ6BXGJCEYNY.SEARCH&ppt=sp&ppn=sp&ssid=b3jspo5c340000001611813456985&qH=f6cdfdaa9f3c23f3"
web.get(url6)
review=[]
rating=[]
summary=[]
ra=web.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
for i in ra[0:22]:
    r1=i.text
    rating.append(r1)
re=web.find_elements_by_xpath("//p[@class='_2-N8zT']")
for i in re[0:22]:
    r2=i.text
    review.append(r2)
ru=web.find_elements_by_xpath("//div[@class='t-ZTKy']")
for i in ru[0:22]:
    
    r3=i.text
    summary.append(r3)

# %%
url61="https://www.flipkart.com/apple-iphone-11-purple-64-gb/p/itm2b8d03427ddac?pid=MOBFWQ6BTFFJKGKE&lid=LSTMOBFWQ6BTFFJKGKE6U3GXK&marketplace=FLIPKART&srno=s_1_3&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&fm=SEARCH&iid=d8a6e448-56d9-44da-91b9-80e9c988a643.MOBFWQ6BTFFJKGKE.SEARCH&ppt=sp&ppn=sp&ssid=b3jspo5c340000001611813456985&qH=f6cdfdaa9f3c23f3"
web.get(url61)
review1=[]
rating1=[]
summary1=[]
ra=web.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
for i in ra[0:22]:
    r1=i.text
    rating1.append(r1)
re=web.find_elements_by_xpath("//p[@class='_2-N8zT']")
for i in re[0:22]:
    r2=i.text
    review1.append(r2)
ru=web.find_elements_by_xpath("//div[@class='t-ZTKy']")
for i in ru[0:22]:
    
    r3=i.text
    summary1.append(r3)

# %%
review2
# Out:
# ['Perfect product!',
#  'Great product',
#  'Perfect product!',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
url62='https://www.flipkart.com/apple-iphone-11-black-64-gb/p/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZE3ENS&marketplace=FLIPKART&srno=s_1_2&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&fm=SEARCH&iid=d8a6e448-56d9-44da-91b9-80e9c988a643.MOBFWQ6BXGJCEYNY.SEARCH&ppt=sp&ppn=sp&ssid=b3jspo5c340000001611813456985&qH=f6cdfdaa9f3c23f3'
web.get(url62)
review2=[]
rating2=[]
summary2=[]
ra=web.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
for i in ra[0:22]:
    r1=i.text
    rating2.append(r1)
re=web.find_elements_by_xpath("//p[@class='_2-N8zT']")
for i in re[0:22]:
    r2=i.text
    review2.append(r2)
ru=web.find_elements_by_xpath("//div[@class='t-ZTKy']")
for i in ru[0:22]:
    
    r3=i.text
    summary2.append(r3)

# %%
url63="https://www.flipkart.com/apple-iphone-11-green-64-gb/p/itm386a85013a3d1?pid=MOBFWQ6BHPMG29QM&lid=LSTMOBFWQ6BHPMG29QM9K4WVV&marketplace=FLIPKART&srno=s_1_4&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&fm=SEARCH&iid=d8a6e448-56d9-44da-91b9-80e9c988a643.MOBFWQ6BHPMG29QM.SEARCH&ppt=sp&ppn=sp&ssid=b3jspo5c340000001611813456985&qH=f6cdfdaa9f3c23f3"
web.get(url63)
review3=[]
rating3=[]
summary3=[]
ra=web.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
for i in ra[0:1]:
    r1=i.text
    rating3.append(r1)
re=web.find_elements_by_xpath("//p[@class='_2-N8zT']")
for i in re[0:1]:
    r2=i.text
    review3.append(r2)
ru=web.find_elements_by_xpath("//div[@class='t-ZTKy']")
for i in ru[0:1]:
    
    r3=i.text
    summary3.append(r3)

# %%
answer7=pd.DataFrame({})
answer7['Rating']=rating+rating1+rating2+rating3
answer7['Review']=review+review1+review2+review3
answer7['Total Summanry']=summary+summary1+summary2+summary3

# %%
# asnwer 7(unable to scarape the data exacatly )
answer7
# Out:
#    Rating            Review                                     Total Summanry
# 0       5  Perfect product!  Amazing phone with great cameras and better ba...
# 1       5     Great product  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 2       5  Perfect product!  It’s a must buy who is looking for an upgrade ...
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10      5  Perfect product!  Amazing phone with great cameras and better ba...
# 11      5     Great product  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 12      5  Perfect product!  It’s a must buy who is looking for an upgrade ...
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20      5  Perfect product!  Amazing phone with great cameras and better ba...
# 21      5     Great product  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 22      5  Perfect product!  It’s a must buy who is looking for an upgrade ...
# 23
# 24
# 25
# 26
# 27
# 28
# 29
# 30      5  Perfect product!  Amazing phone with great cameras and better ba...

# %%
# question 8
url8="https://www.flipkart.com/search?q=sneakers&sid=osp%2Ccil%2Ce1f&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=sneakers%7CMen%27s+Casual+Shoes&requestId=99e4abe8-784d-4094-a150-9f79077dec53&as-searchtext=sne"
web.get(url8)
brand=[]
prd_descr=[]
price=[]
dis=[]
b=web.find_elements_by_xpath("//div[@class='_2WkVRV']")
for i in b[0:]:
    bi=i.text
    brand.append(bi)
p=web.find_elements_by_xpath("//a[@class='IRpwTa']")
for i in p[0:100]:
    pi=i.text
    prd_descr.append(pi)
pr=web.find_elements_by_xpath("//div[@class='_30jeq3']")
for i in pr[0:100]:
    ci=i.text
    price.append(ci)
d=web.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
for  i in d[0:100]:
    di=i.text
    dis.append(di)

# %%
url81="https://www.flipkart.com/search?q=sneakers&sid=osp%2Ccil%2Ce1f&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=sneakers%7CMen%27s+Casual+Shoes&requestId=99e4abe8-784d-4094-a150-9f79077dec53&as-searchtext=sne&page=2"
web.get(url81)
brand1=[]
prd_descr12=[]
price1=[]
dis1=[]
b1=web.find_elements_by_xpath("//div[@class='_2WkVRV']")
for i in b1:
    bi=i.text
    brand1.append(bi)
p=web.find_elements_by_xpath("//a[@class='IRpwTa']")
for i in p[0:98]:
    pi=i.text
    prd_descr12.append(pi)
pr=web.find_elements_by_xpath("//div[@class='_30jeq3']")
for i in pr[0:100]:
    ci=i.text
    price1.append(ci)
d=web.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
for  i in d[0:100]:
    di=i.text
    dis1.append(di)    
url82="https://www.flipkart.com/search?q=sneakers&sid=osp%2Ccil%2Ce1f&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=sneakers%7CMen%27s+Casual+Shoes&requestId=99e4abe8-784d-4094-a150-9f79077dec53&as-searchtext=sne&page=3"
web.get(url82)
brand2=[]
prd_descr2=[]
price2=[]
dis2=[]
b2=web.find_elements_by_xpath("//div[@class='_2WkVRV']")
for i in b2[0:20]:
    bi=i.text
    brand2.append(bi)
p=web.find_elements_by_xpath("//a[@class='IRpwTa']")
for i in p[0:31]:
    pi=i.text
    prd_descr2.append(pi)
pr=web.find_elements_by_xpath("//div[@class='_30jeq3']")
for i in pr[0:20]:
    ci=i.text
    price2.append(ci)
d=web.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
for  i in d[0:21]:
    di=i.text
    dis2.append(di)

# %%
a=prd_descr+prd_descr12+prd_descr2


len(a)
# Out:
# 100

# %%
ans8=pd.DataFrame({})
ans8['Brand Name']=brand+brand1+brand2

ans8['price']=price+price1+price2
ans8['discount']=dis+dis1+dis2
ans8['Product description']=a

# %%
#Answer 8
ans8
# Out:
#              Brand Name   price discount  \
# 0                Chevit    ₹499  75% off
# 1   World Wear Footwear    ₹499  75% off
# 2          Robbie jones    ₹378  62% off
# 3            Restinfoot    ₹350  64% off
# 4                Chevit    ₹224  55% off
# ..                  ...     ...      ...
# 95                 Nike  ₹2,022  23% off
# 96                Sparx    ₹769  49% off
# 97               REEBOK  ₹6,119  70% off
# 98               Chevit    ₹299  80% off
# 99               BRUTON    ₹799  23% off
#
#                                   Product description
# 0   Combo Pack of 4 Casual Sneakers With Sneakers ...
# 1   Combo Pack of 4 Latest Collection Stylish Casu...
# 2      Casual Sneakers Shoes For Men Sneakers For Men
# 3   Casual shoes,Sneakers for men's,shoes for men'...
# 4   171 Smart Tan Lace-Ups Casuals for Men Sneaker...
# ..                                                ...
# 95                                   Sneakers For Men
# ...

# %%
#question 9
url9="https://www.myntra.com/shoes?f=Color%3ABlack_36454f&plaEnabled=false&rf=Price%3A5899.0_11599.0_5899.0%20TO%2011599.0"
web.get(url9)

# %%
brand=[]
describe=[]
pric=[]
p=web.find_elements_by_xpath("//span[@class='product-discountedPrice']")
for i in p[0:]:
    pi=i.text
    pric.append(pi)
d=web.find_elements_by_xpath("//h4[@class='product-product']")
for i in d[0:]:
    di=i.text
    describe.append(di)
b=web.find_elements_by_xpath("//h3[@class='product-brand']")
for i in b:
    bi=i.text
    brand.append(bi)

# %%
len(brand)
# Out:
# 50

# %%
url91='https://www.myntra.com/shoes?f=Color%3ABlack_36454f&p=2&plaEnabled=false&rf=Price%3A5899.0_11599.0_5899.0%20TO%2011599.0'
web.get(url91)
brand1=[]
describe1=[]
pric1=[]
p=web.find_elements_by_xpath("//span[@class='product-discountedPrice']")
for i in p[0:]:
    pi=i.text
    pric1.append(pi)
d=web.find_elements_by_xpath("//h4[@class='product-product']")
for i in d[0:]:
    di=i.text
    describe1.append(di)
b=web.find_elements_by_xpath("//h3[@class='product-brand']")
for i in b:
    bi=i.text
    brand1.append(bi)

# %%
url92='https://www.myntra.com/shoes?f=Color%3ABlack_36454f&p=3&plaEnabled=false&rf=Price%3A5899.0_11599.0_5899.0%20TO%2011599.0'
web.get(url92)

describe2=[]
pric3=[]
p=web.find_elements_by_xpath("//span[@class='product-discountedPrice']")
for i in p[0:8]:
    pi=i.text
    pric3.append(pi)
d=web.find_elements_by_xpath("//h4[@class='product-product']")
for i in d[0:12]:
    di=i.text
    describe2.append(di)

# %%
len(describe+describe1+describe2)
# Out:
# 112

# %%
ans9=pd.DataFrame({})
ans9['Brand Name']=brand+brand1

ans9['price']=pric+pric1+pric3

ans9['Product description']=describe+describe1

# %%
#Answer 9
ans9
# Out:
#         Brand Name      price             Product description
# 0        Cole Haan   Rs. 8249                Leather Sneakers
# 1             Nike   Rs. 9999     Men JORDAN DELTA Basketball
# 2             Nike  Rs. 11199    Men ZOOM FLY 3 Running Shoes
# 3             Nike   Rs. 6599      Men LEGEND REACT 3 Running
# 4             Puma   Rs. 6599  Men HYBRID NETFIT Running Shoe
# ..             ...        ...                             ...
# 95    UNDER ARMOUR   Rs. 6199   Charged Impulse Running Shoes
# 96  Tommy Hilfiger   Rs. 8994      Men Colourblocked Sneakers
# 97  Tommy Hilfiger   Rs. 6293   Men Heritage Leather Sneakers
# 98  Tommy Hilfiger   Rs. 7999   Men Solid TS Sport 2 Sneakers
# 99            Xtep   Rs. 9513      AIR MEGA Energy Ring Shoes
#
# [100 rows x 3 columns]

# %%
#question 10
url10="https://www.amazon.in/s?k=laptop&i=computers&rh=n%3A1375424031%2Cp_n_feature_thirteen_browse-bin%3A12598163031%7C16757432031&dc&qid=1611335282&rnid=12598141031&ref=sr_nr_p_n_feature_thirteen_browse-bin_17"
web.get(url10)
title=[]
ra=[]
price=[]
t=web.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
for i in t[0:10]:
    ti=i.text
    title.append(ti)
r=web.find_elements_by_xpath("//span[@class='a-declarative']")
for i in r:
    ri=i.text
    ra.append(ri)
p=web.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in p[0:10]:
    pi=i.text
    price.append(pi)

# %%
# unable to scrape rating
ans10=pd.DataFrame({})
ans10["Title"]=title
ans10['Price']=price
ans10
# Out:
#                                                Title   Price
# 0  HP Pavilion x360 Core i7 8th Gen 14-inch Touch...  82,490
# 1  Mi Notebook Horizon Edition 14 Intel Core i7-1...  57,999
# 2  (Renewed) MSI Prestige PE62 Core i7 7th Gen 15...  57,990
# 3  Mi Notebook Horizon Edition 14 Intel Core i5-1...  51,999
# 4  (Renewed) ASUS ROG Strix G G531GT-AL041T 15.6"...  71,990
# 5  Lenovo Yoga S740 Intel Core i7 10th Gen 14 inc...  97,700
# 6  (Renewed) ASUS ROG Strix G G531GT-AL018T 15.6"...  69,990
# 7  Lenovo IdeaPad Gaming 3i 10th Gen Intel Core i...  74,990
# 8  (Renewed) HP Probook Laptop 430G3 Intel Core i...  48,990
# 9  (CERTIFIED REFURBISHED) ASUS Rog Strix GL503GE...  65,990
